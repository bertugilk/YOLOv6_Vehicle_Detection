# %% [markdown]
# ### Clone YOLOv6

# %%
# !git clone https://github.com/meituan/YOLOv6
# Out:
# Cloning into 'YOLOv6'...

# %% [markdown]
# ### Install Pytorch library

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
import torch
torch.cuda.is_available() 
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3070 Laptop GPU'

# %%
# %cd C:/Users/bertu/Vehicle_Detection/YOLOv6
# Out:
# C:\Users\bertu\Vehicle_Detection\YOLOv6

# %%
pwd
# Out:
# 'C:\\Users\\bertu\\Vehicle_Detection\\YOLOv6'

# %%
# !more "C:\Users\bertu\Vehicle_Detection\Data\data.yaml"
# Out:
# train: C:\Users\bertu\Vehicle_Detection\Data\images\train
# val: C:\Users\bertu\Vehicle_Detection\Data\images\valid
# test: C:\Users\bertu\Vehicle_Detection\Data\images\test
#
# nc: 5
# names: ['Ambulance', 'Bus', 'Car', 'Motorcycle', 'Truck']

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### TRAIN

# %%
# !python tools/train.py --batch 16 --conf configs/yolov6s_finetune.py --data-path "C:\Users\bertu\Vehicle_Detection\Data\data.yaml" --device 0 --epochs 30 --eval-interval 2
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.107
# ...

# %% [markdown]
# ### Evaluation

# %%
# !python tools/eval.py --data "C:\Users\bertu\Vehicle_Detection\Data\data.yaml"  --weights C:\Users\bertu\Vehicle_Detection\YOLOv6\runs\train\exp11\weights\best_ckpt.pt --device 0
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.35s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.06s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.675
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.751
# ...

# %% [markdown]
# ### Inference

# %%
# !python tools/infer.py --weights C:\Users\bertu\Vehicle_Detection\YOLOv6\runs\train\exp11\weights\best_ckpt.pt --source C:\Users\bertu\Vehicle_Detection\Data\images\test\c0a105b4fe3a7c55_jpg.rf.28745179cd0f87dc9cae886872f95263.jpg --yaml "C:\Users\bertu\Vehicle_Detection\Data\data.yaml" --device 0
# Out:
# Namespace(weights='C:\\Users\\bertu\\Vehicle_Detection\\YOLOv6\\runs\\train\\exp11\\weights\\best_ckpt.pt', source='C:\\Users\\bertu\\Vehicle_Detection\\Data\\images\\test\\c0a105b4fe3a7c55_jpg.rf.28745179cd0f87dc9cae886872f95263.jpg', yaml='C:\\Users\\bertu\\Vehicle_Detection\\Data\\data.yaml', img_size=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='0', save_txt=False, save_img=True, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Loading checkpoint from C:\Users\bertu\Vehicle_Detection\YOLOv6\runs\train\exp11\weights\best_ckpt.pt
#
# Fusing model...
# Switch model to deploy modality.
#
# ...
# 100%|##########| 1/1 [00:00<00:00, 28.97it/s]
# Results saved to runs/inference\exp

# %%
from IPython.display import Image #this is to render predictions
Image(filename=r'C:\Users\bertu\Vehicle_Detection\YOLOv6\runs\inference\exp\c0a105b4fe3a7c55_jpg.rf.28745179cd0f87dc9cae886872f95263.jpg', width=1000)
